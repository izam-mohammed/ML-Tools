# %% [markdown]
# ensure is a set of simple assertion helpers that let you write more expressive, literate, concise, and readable Pythonic code for validating conditions.

# %%
# installing

# !pip install ensure --quiet

# %%
# ensure annotation

from ensure import ensure_annotations

@ensure_annotations
def func(x:int, y:int) -> float:
  return x * y

# %%
func(2,4)
# Out:
# 0.5

# %%
try:
  print(func(4,8.4))
except Exception as e:
  print("error found")
  print(e)
# Out:
# error found
# Argument y of type <class 'float'> to <function func at 0x7ce0ddb4caf0> does not match annotation type <class 'int'>

# %% [markdown]
# That's it
