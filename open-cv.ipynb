# %% [markdown]
# OpenCV provides a real-time optimized Computer Vision library, tools, and hardware.

# %% [markdown]
# All of the code related to open-cv is available in [this repository](https://github.com/izam-mohammed/OpenCV-cookbook)
