# %%
import pandas as pd
from category_encoders import OrdinalEncoder
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor

# %%
from shapash.data.data_loader import data_loading
house_df, house_dict = data_loading('house_prices')

# %%
y_df=house_df['SalePrice'].to_frame()
X_df=house_df[house_df.columns.difference(['SalePrice'])]

# %%
house_df.shape
# Out:
# (1460, 73)

# %%
house_df.head()
# Out:
#                          MSSubClass                 MSZoning  LotArea Street  \
# Id
# 1              2-Story 1946 & Newer  Residential Low Density     8450  Paved
# 2   1-Story 1946 & Newer All Styles  Residential Low Density     9600  Paved
# 3              2-Story 1946 & Newer  Residential Low Density    11250  Paved
# 4              2-Story 1945 & Older  Residential Low Density     9550  Paved
# 5              2-Story 1946 & Newer  Residential Low Density    14260  Paved
#
#               LotShape      LandContour                         Utilities  \
# Id
# 1              Regular  Near Flat/Level  All public Utilities (E,G,W,& S)
# 2              Regular  Near Flat/Level  All public Utilities (E,G,W,& S)
# 3   Slightly irregular  Near Flat/Level  All public Utilities (E,G,W,& S)
# 4   Slightly irregular  Near Flat/Level  All public Utilities (E,G,W,& S)
# 5   Slightly irregular  Near Flat/Level  All public Utilities (E,G,W,& S)
#
#                           LotConfig     LandSlope   Neighborhood  ...  \
# Id                                                                ...
# 1                        Inside lot  Gentle slope  College Creek  ...
# 2   Frontage on 2 sides of property  Gentle slope        Veenker  ...
# 3                        Inside lot  Gentle slope  College Creek  ...
# 4                        Corner lot  Gentle slope       Crawford  ...
# 5   Frontage on 2 sides of property  Gentle slope     Northridge  ...
#
#    EnclosedPorch 3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  \
# Id
# 1              0         0           0        0        0       2    2008
# 2              0         0           0        0        0       5    2007
# 3              0         0           0        0        0       9    2008
# 4            272         0           0        0        0       2    2006
# 5              0         0           0        0        0      12    2008
#
#                         SaleType  SaleCondition SalePrice
# Id
# 1   Warranty Deed - Conventional    Normal Sale    208500
# 2   Warranty Deed - Conventional    Normal Sale    181500
# 3   Warranty Deed - Conventional    Normal Sale    223500
# 4   Warranty Deed - Conventional  Abnormal Sale    140000
# 5   Warranty Deed - Conventional    Normal Sale    250000
#
# [5 rows x 73 columns]

# %%
from category_encoders import OrdinalEncoder

categorical_features = [col for col in X_df.columns if X_df[col].dtype == 'object']

encoder = OrdinalEncoder(
    cols=categorical_features,
    handle_unknown='ignore',
    return_df=True).fit(X_df)

X_df=encoder.transform(X_df)

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X_df, y_df, train_size=0.75, random_state=1)

# %%
regressor = LGBMRegressor(n_estimators=100).fit(Xtrain,ytrain)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001255 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2986
# [LightGBM] [Info] Number of data points in the train set: 1095, number of used features: 66
# [LightGBM] [Info] Start training from score 182319.757078

# %%
from shapash import SmartExplainer

# %%
xpl = SmartExplainer(
    model=regressor,
    preprocessing=encoder,   # Optional: compile step can use inverse_transform method
    features_dict=house_dict # optional parameter, specifies label for features name
)

# %%
xpl.compile(x=Xtest,
            y_target=ytest # Optional: allows to display True Values vs Predicted Values
           )
# Out:
# INFO: Shap explainer type - <shap.explainers._tree.TreeExplainer object at 0x780afefa6aa0>

# %%
app = xpl.run_app(title_story='House Prices', port=8020)

# %%
app.kill()

# %%
xpl.plot.features_importance()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0feeaefc-32ce-4b0e-8412-a60c47c8d942" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0feeaefc-32ce-4b0e-8412-a60c47c8d942")) {                    Plotly.newPlot(                        "0feeaefc-32ce-4b0e-8412-a60c47c8d942",                        [{"customdata":["Second floor square feet","General shape of property","Exterior materials' quality","Physical locations within Ames city limits","Rating of basement finished area","Total rooms above grade","Open porch area in square feet","Building Class","Kitchen quality","Overall condition of the house","First Floor square feet","Number of fireplaces","Lot size square feet","Original construction date","Remodel date","Size of garage in square feet","Type 1 finished square feet","Total square feet of basement area","Ground living area square feet","Overall material and finish of the house"],"hovertemplate":"Feature: %{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":["rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)"],"line":{"color":"rgba(52, 55, 54, 0.8)","width":0.5}},"name":"Global","orientation":"h","x":[0.0097,0.0099,0.0107,0.011,0.0111,0.0112,0.0122,0.0141,0.0165,0.0237,0.024,0.0254,0.0335,0.0346,0.0355,0.0372,0.0406,0.0613,0.1438,0.2889],"y":["Second floor square feet","General shape of property","Exterior materials' quality","Physical locations within Ames city limits","Rating of basement finished area","Total rooms above grade","Open porch area in square feet","Building Class","Kitchen quality","Overall condition of the house","First Floor square feet","Number of fireplaces","Lot size square feet","Original construction date","Remodel date","Size of garage in square feet","Type 1 finished square feet","Total square feet of basement area","Ground living area square feet","Overall material and finish of the house"],"type":"bar"}],                        {"autosize":false,"barmode":"group","height":500,"hovermode":"closest","margin":{"b":50,"l":160,"r":0,"t":95},"template":{"data":{"scatter":[{"type":"scatter"}]}},"title":{"font":{"color":"rgb(50, 50, 50)","family":"Arial","size":24},"text":"Features Importance\u003cbr\u003e\u003csup\u003eTotal number of features: 72\u003c\u002fsup\u003e","x":0.5,"xanchor":"center","y":0.9,"yanchor":"middle"},"width":900,"xaxis":{"title":{"font":{"color":"rgb(50, 50, 50)","family":"Arial Black","size":16},"text":"Mean absolute Contribution"}},"yaxis":{"title":{"font":{"color":"rgb(50, 50, 50)","family":"Arial Black","size":16}},"ticktext":["Second floor square feet","General shape of property","Exterior materials' quality","Physical locations withi...its","Rating of basement finis...rea","Total rooms above grade","Open porch area in square feet","Building Class","Kitchen quality","Overall condition of the house","First Floor square feet","Number of fireplaces","Lot size square feet","Original construction date","Remodel date","Size of garage in square feet","Type 1 finished square feet","Total square feet of bas...rea","Ground living area square feet","Overall material and fin...use"],"tickvals":["Second floor square feet","General shape of property","Exterior materials' quality","Physical locations within Ames city limits","Ra ...
#
# var gd = document.getElementById('0feeaefc-32ce-4b0e-8412-a60c47c8d942');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %%
subset = [ 168, 54, 995, 799, 310, 322, 1374,
          1106, 232, 645, 1170, 1229, 703, 66,
          886, 160, 191, 1183, 1037, 991, 482,
          725, 410, 59, 28, 719, 337, 36]
xpl.plot.features_importance(selection=subset)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="593bbe3b-c822-4b12-90eb-e6e1e05f572b" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("593bbe3b-c822-4b12-90eb-e6e1e05f572b")) {                    Plotly.newPlot(                        "593bbe3b-c822-4b12-90eb-e6e1e05f572b",                        [{"customdata":["Second floor square feet","General shape of property","Exterior materials' quality","Physical locations within Ames city limits","Rating of basement finished area","Total rooms above grade","Open porch area in square feet","Building Class","Kitchen quality","Overall condition of the house","First Floor square feet","Number of fireplaces","Lot size square feet","Original construction date","Remodel date","Size of garage in square feet","Type 1 finished square feet","Total square feet of basement area","Ground living area square feet","Overall material and finish of the house"],"hovertemplate":"Feature: %{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(52, 55, 54, 0.7)"},"name":"Subset","orientation":"h","x":[0.0098,0.0059,0.0169,0.0047,0.004,0.0241,0.0077,0.0065,0.028,0.0065,0.0248,0.011,0.0368,0.0213,0.0166,0.0293,0.039,0.0475,0.1389,0.4162],"y":["Second floor square feet","General shape of property","Exterior materials' quality","Physical locations within Ames city limits","Rating of basement finished area","Total rooms above grade","Open porch area in square feet","Building Class","Kitchen quality","Overall condition of the house","First Floor square feet","Number of fireplaces","Lot size square feet","Original construction date","Remodel date","Size of garage in square feet","Type 1 finished square feet","Total square feet of basement area","Ground living area square feet","Overall material and finish of the house"],"type":"bar"},{"customdata":["Second floor square feet","General shape of property","Exterior materials' quality","Physical locations within Ames city limits","Rating of basement finished area","Total rooms above grade","Open porch area in square feet","Building Class","Kitchen quality","Overall condition of the house","First Floor square feet","Number of fireplaces","Lot size square feet","Original construction date","Remodel date","Size of garage in square feet","Type 1 finished square feet","Total square feet of basement area","Ground living area square feet","Overall material and finish of the house"],"hovertemplate":"Feature: %{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":["rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)","rgba(244, 192, 0, 1.0)"],"line":{"color":"rgba(52, 55, 54, 0.8)","width":0.5}},"name":"Global","orientation":"h","x":[0.0097,0.0099,0.0107,0.011,0.0111,0.0112,0.0122,0.0141,0.0165,0.0237,0.024,0.0254,0.0335,0.0346,0.0355,0.0372,0.0406,0.0613,0.1438,0.2889],"y":["Second floor square feet","General shape of property","Exterior materials' quality","Physical locations within Ames city limits","Rating of basement finished area","Total rooms above grade","Open porch area in square feet","Building Class","Kitchen quality","Overall condition of the house","First Floor square feet","Number of fireplaces","Lot size square feet","Original construction date","Remodel date","S ...
#
# var gd = document.getElementById('593bbe3b-c822-4b12-90eb-e6e1e05f572b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %%
xpl.plot.contribution_plot("OverallQual")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="93fc3ad5-a9e9-430a-9ffe-0012ca52f47f" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93fc3ad5-a9e9-430a-9ffe-0012ca52f47f")) {                    Plotly.newPlot(                        "93fc3ad5-a9e9-430a-9ffe-0012ca52f47f",                        [{"hovertext":["Id: 376\u003cbr \u002f\u003ePredict: 64803.0"],"line":{"color":"rgba(117, 152, 189, 0.9)"},"meanline":{"visible":true},"scalemode":"count","showlegend":false,"x":[1],"y":[-40520.91489449654],"type":"violin","customdata":[[7,259],[5,268],[5,289],[4,650],[5,1234],[8,168],[8,927],[7,832],[7,1238],[7,427],[5,488],[1,376],[7,1127],[9,54],[7,1034],[5,1023],[5,1216],[5,92],[7,1271],[6,681],[5,465],[4,1417],[8,731],[10,995],[6,384],[6,993],[6,532],[7,743],[9,799],[5,433],[5,810],[6,1030],[5,195],[4,1145],[5,38],[9,310],[6,312],[4,977],[7,1044],[4,1449],[5,293],[6,425],[5,326],[5,1070],[6,1109],[6,1007],[7,1149],[7,983],[8,284],[7,1254],[5,260],[7,305],[5,269],[8,1134],[7,1075],[5,108],[5,1102],[7,112],[5,805],[6,102],[6,834],[8,302],[4,342],[5,953],[5,660],[5,485],[6,654],[7,1058],[5,1435],[5,1054],[5,1174],[4,49],[8,322],[7,853],[5,1077],[7,820],[7,1125],[5,967],[10,1374],[7,444],[6,81],[4,585],[5,588],[5,1027],[7,767],[5,1094],[6,1074],[6,61],[6,1211],[6,892],[7,598],[6,811],[4,141],[4,1233],[5,762],[5,1275],[5,1221],[5,20],[6,755],[5,539],[5,954],[5,593],[4,1409],[4,1341],[5,1114],[7,736],[6,923],[7,4],[6,841],[8,1106],[5,842],[5,608],[6,773],[7,237],[8,738],[6,120],[8,931],[5,50],[5,178],[8,170],[5,1378],[8,825],[8,232],[7,105],[6,1069],[6,1147],[9,645],[5,813],[7,686],[7,573],[7,409],[3,1001],[5,817],[5,840],[5,265],[6,753],[10,1170],[9,1229],[7,256],[6,742],[5,109],[6,962],[6,920],[7,560],[4,31],[7,383],[5,419],[7,783],[7,1339],[5,932],[7,781],[6,858],[4,224],[6,1135],[7,349],[8,703],[3,89],[5,1222],[4,751],[5,1368],[2,637],[5,694],[6,600],[6,780],[6,973],[5,1419],[6,1359],[5,1270],[5,331],[5,536],[7,159],[6,1264],[7,930],[8,818],[6,1261],[5,1130],[6,517],[6,95],[5,1011],[6,786],[5,680],[7,709],[5,944],[5,1228],[8,1110],[5,580],[8,582],[8,66],[6,547],[6,572],[4,901],[5,1230],[6,228],[8,57],[5,143],[8,404],[7,1204],[6,522],[6,300],[4,1324],[7,436],[7,919],[6,854],[6,1067],[9,886],[5,205],[7,1455],[7,160],[8,191],[5,336],[7,249],[5,1115],[6,116],[4,538],[8,479],[8,271],[5,1253],[3,737],[5,1185],[4,76],[10,1183],[5,463],[6,756],[7,1356],[5,391],[5,513],[8,454],[6,683],[6,88],[7,574],[5,1334],[7,821],[4,730],[5,695],[9,1037],[5,895],[8,760],[4,1315],[4,1363],[8,991],[9,482],[7,182],[4,877],[4,1263],[5,862],[6,199],[5,1232],[6,492],[5,562],[6,121],[5,499],[6,373],[7,1247],[6,202],[5,1012],[6,52],[7,187],[4,529],[9,725],[5,1082],[8,134],[5,1224],[7,1241],[6,82],[5,491],[6,925],[5,423],[7,981],[6,675],[6,1379],[7,1440],[6,1085],[5,387],[5,1132],[5,1142],[5,1180],[5,1105],[5,13],[6,1060],[5,74],[5,787],[5,958],[5,1146],[5,1205],[8,461],[7,303],[6,1286],[4,164],[8,48],[4,1433],[5,99],[8,410],[5,922],[4,521],[7,402],[7,281],[6,1402],[6,132],[5,809],[5,1250],[6,1084],[5,614],[5,216],[7,136],[6,635],[6,447],[6,626],[6,299],[5,1337],[7,526],[6,630],[6,1284],[4,712],[7,777],[6,196],[4,1326],[8,1290],[7,1107],[6,1430],[5,599],[7,1189],[6,1072],[5,946],[7,415],[5,986],[10,59],[7,791],[7,1427],[6,240],[6,672],[5,1177],[8,721],[7,1375],[8,28],[6,405],[5,1004],[6,127],[4,1207],[7,719],[6,1196],[7,816],[7,504],[4,936],[8,641],[4,91],[5,926],[6,831],[6,263],[9,766],[5,590],[7,400],[7,149],[9,337],[5,369],[5,557],[4,79],[7,651],[5,881],[4,822],[8,36],[8,1018],[8,535],[5,1335],[8,1370],[5,629]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr \u002f\u003eOverall material and finish of the house :\u003cbr \u002f\u003e%{customdata[0]}\u003cbr \u002f\u003eContribut ...

# %%
xpl.plot.contribution_plot("Second floor square feet")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="36cbc085-5b2c-4500-8812-8bc27f54b3df" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36cbc085-5b2c-4500-8812-8bc27f54b3df")) {                    Plotly.newPlot(                        "36cbc085-5b2c-4500-8812-8bc27f54b3df",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr \u002f\u003eSecond floor square feet: %{customdata[0]}\u003cbr \u002f\u003eContribution: %{y:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Id: 259\u003cbr \u002f\u003ePredict: 209880.0","Id: 268\u003cbr \u002f\u003ePredict: 176533.0","Id: 289\u003cbr \u002f\u003ePredict: 114424.0","Id: 650\u003cbr \u002f\u003ePredict: 74222.0","Id: 1234\u003cbr \u002f\u003ePredict: 137560.0","Id: 168\u003cbr \u002f\u003ePredict: 336292.0","Id: 927\u003cbr \u002f\u003ePredict: 314087.0","Id: 832\u003cbr \u002f\u003ePredict: 147661.0","Id: 1238\u003cbr \u002f\u003ePredict: 231424.0","Id: 427\u003cbr \u002f\u003ePredict: 214284.0","Id: 488\u003cbr \u002f\u003ePredict: 175938.0","Id: 376\u003cbr \u002f\u003ePredict: 64803.0","Id: 1127\u003cbr \u002f\u003ePredict: 188304.0","Id: 54\u003cbr \u002f\u003ePredict: 263994.0","Id: 1034\u003cbr \u002f\u003ePredict: 238329.0","Id: 1023\u003cbr \u002f\u003ePredict: 112648.0","Id: 1216\u003cbr \u002f\u003ePredict: 115068.0","Id: 92\u003cbr \u002f\u003ePredict: 117237.0","Id: 1271\u003cbr \u002f\u003ePredict: 215825.0","Id: 681\u003cbr \u002f\u003ePredict: 123421.0","Id: 465\u003cbr \u002f\u003ePredict: 119392.0","Id: 1417\u003cbr \u002f\u003ePredict: 112376.0","Id: 731\u003cbr \u002f\u003ePredict: 280224.0","Id: 995\u003cbr \u002f\u003ePredict: 355020.0","Id: 384\u003cbr \u002f\u003ePredict: 72330.0","Id: 993\u003cbr \u002f\u003ePredict: 196833.0","Id: 532\u003cbr \u002f\u003ePredict: 126906.0","Id: 743\u003cbr \u002f\u003ePredict: 188560.0","Id: 799\u003cbr \u002f\u003ePredict: 489480.0","Id: 433\u003cbr \u002f\u003ePredict: 127766.0","Id: 810\u003cbr \u002f\u003ePredict: 112036.0","Id: 1030\u003cbr \u002f\u003ePredict: 115888.0","Id: 195\u003cbr \u002f\u003ePredict: 126453.0","Id: 1145\u003cbr \u002f\u003ePredict: 77668.0","Id: 38\u003cbr \u002f\u003ePredict: 148487.0","Id: 310\u003cbr \u002f\u003ePredict: 352284.0","Id: 312\u003cbr \u002f\u003ePredict: 128465.0","Id: 977\u003cbr \u002f\u003ePredict: 82975.0","Id: 1044\u003cbr \u002f\u003ePredict: 281803.0","Id: 1449\u003cbr \u002f\u003ePredict: 89458.0","Id: 293\u003cbr \u002f\u003ePredict: 145659.0","Id: 425\u003cbr \u002f\u003ePredict: 140979.0","Id: 326\u003cbr \u002f\u003ePredict: 88113.0","Id: 1070\u003cbr \u002f\u003ePredict: 126888.0","Id: 1109\u003cbr \u002f\u003ePredict: 174257.0","Id: 1007\u003cbr \u002f\u003ePredict: 150350.0","Id: 1149\u003cbr \u002f\u003ePredict: 124601.0","Id: 983\u003cbr \u002f\u003ePredict: 176876.0","Id: 284\u003cbr \u002f\u003ePredict: 267560.0","Id: 1254\u003cbr \u002f\u003ePredict: 260091.0","Id: 260\u003cbr \u002f\u003ePredict: 121338.0","Id: 305\u003cbr \u002f\u003ePredict: 296793.0","Id: 269\u003cbr \u002f\u003ePredict: 127198.0","Id: 1134\u003cbr \u002f\u003ePredict: 211224.0","Id: 1075\u003cbr \u002f\u003ePredict: 197450.0","Id: 108\u003cbr \u002f\u003ePredict: 98353.0","Id: 1102\u003cbr \u002f\u003ePredict: 120266.0","Id: 112\u003cbr \u002f\u003ePredict: 165526.0","Id: 805\u003cbr \u002f\u003ePredict: 119961.0","Id: 102\u003cbr \u002f\u003ePredict: 173525.0","Id: 834\u003cbr \u002f\u003ePredict: 161226.0","Id: 302\u003cbr \u002f\u003ePredict: 291081.0","Id: 342\u003cbr \u002f\u003ePredict: 89800.0","Id: 953\u003cbr \u002f\u003ePredict: 134788.0","Id: 660\u003cbr \u002f\u003ePredict: 171746.0","Id: 485\u003cbr \u002f\u003ePredict: 125893.0","Id: 654\u003cbr \u002f\u003ePredict ...

# %%
xpl.plot.local_plot(index=560)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c404470d-9725-4707-aa5c-11a27903375a" class="plotly-graph-div" style="height:550px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c404470d-9725-4707-aa5c-11a27903375a")) {                    Plotly.newPlot(                        "c404470d-9725-4707-aa5c-11a27903375a",                        [{"customdata":["\u003cb\u003eHidden Negative Contributions\u003c\u002fb\u003e"],"hovertemplate":"%{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(52, 55, 54, 0.7)","line":{"color":"rgba(27, 28, 28, 1.0)","width":0.5}},"orientation":"h","showlegend":false,"x":[-6201.364681891189],"y":["\u003ci\u003eHidden Negative Contributions\u003c\u002fi\u003e"],"type":"bar"},{"customdata":["\u003cb\u003eLot size square feet :\u003c\u002fb\u003e\u003cbr \u002f\u003e3196"],"hovertemplate":"%{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(74, 99, 138, 0.7)","line":{"color":"rgba(27, 28, 28, 1.0)","width":0.5}},"orientation":"h","showlegend":false,"x":[-7861.005668103792],"y":["\u003cb\u003eLot size square feet\u003c\u002fb\u003e"],"type":"bar"},{"customdata":["\u003cb\u003eGround living area square feet :\u003c\u002fb\u003e\u003cbr \u002f\u003e1557"],"hovertemplate":"%{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(74, 99, 138, 0.7)","line":{"color":"rgba(27, 28, 28, 1.0)","width":0.5}},"orientation":"h","showlegend":false,"x":[-4645.026120692127],"y":["\u003cb\u003eGround living area square feet\u003c\u002fb\u003e"],"type":"bar"},{"customdata":["\u003cb\u003eType 1 finished square feet :\u003c\u002fb\u003e\u003cbr \u002f\u003e0"],"hovertemplate":"%{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(74, 99, 138, 0.7)","line":{"color":"rgba(27, 28, 28, 1.0)","width":0.5}},"orientation":"h","showlegend":false,"x":[-3837.9651567034302],"y":["\u003cb\u003eType 1 finished square feet\u003c\u002fb\u003e"],"type":"bar"},{"customdata":["\u003cb\u003eBuilding Class :\u003c\u002fb\u003e\u003cbr \u002f\u003e1-Story PUD (Planned Unit Development) - 1946 &\u003cbr \u002f\u003eNewer"],"hovertemplate":"%{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(74, 99, 138, 0.7)","line":{"color":"rgba(27, 28, 28, 1.0)","width":0.5}},"orientation":"h","showlegend":false,"x":[-2783.165953453229],"y":["\u003cb\u003eBuilding Class\u003c\u002fb\u003e"],"type":"bar"},{"customdata":["\u003cb\u003eOverall condition of the house :\u003c\u002fb\u003e\u003cbr \u002f\u003e5"],"hovertemplate":"%{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(74, 99, 138, 0.7)","line":{"color":"rgba(27, 28, 28, 1.0)","width":0.5}},"orientation":"h","showlegend":false,"x":[-1917.299000346505],"y":["\u003cb\u003eOverall condition of the house\u003c\u002fb\u003e"],"type":"bar"},{"customdata":["\u003cb\u003eSize of garage in square feet :\u003c\u002fb\u003e\u003cbr \u002f\u003e420"],"hovertemplate":"%{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgba(74, 99, 138, 0.7)","line":{"color":"rgba(27, 28, 28, 1.0)","width":0.5}},"orientation":"h","showlegend":false,"x":[-1855.9095490190364],"y":["\u003cb\u003eSize of garage in square feet\u003c\u002fb\u003e"],"type":"bar"},{"customdata":["\u003cb\u003eSecond floor square feet :\u003c\u002fb\u003e\u003cbr \u002f\u003e0"],"hovertemplate":"%{customdata}\u003cbr \u002f\u003eContribution: %{x:.4f}\u003cextra\u003e\u0 ...

# %%
xpl.filter(max_contrib=8,threshold=100)

# %%
summary_df= xpl.to_pandas(
    max_contrib=3, # Number Max of features to show in summary
    threshold=5000,
)

# %%
xpl.save('./xpl.pkl')

# %%
predictor = xpl.to_smartpredictor()
predictor.save('./predictor.pkl')

# %%
from shapash.utils.load_smartpredictor import load_smartpredictor
predictor_load = load_smartpredictor('./predictor.pkl')

# %% [markdown]
# That's all.
