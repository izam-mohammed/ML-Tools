# %% [markdown]
# ### Setting up

# %%
# installing

# !pip install pycaret --quiet
# !pip install pycaret[full] --quiet

# %%
# importing

import pycaret
pycaret.__version__
# Out:
# '3.2.0'

# %% [markdown]
# ## Binary Classification

# %% [markdown]
# ### Data loading

# %%
# loading the data

from pycaret.datasets import get_data
data = get_data('diabetes')
data
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# 766                                                126
# 767                                                 93
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                  72                                35
# 1                                  66                                29
# 2                                  64                                 0
# 3                                  66                                23
# 4                                  40                                35
# ..                                ...                               ...
# 763                                76                                48
# 764                                70                                27
# 765                                72                                23
# 766                                60                                 0
# 767                                70                                31
#
#      2-Hour serum insulin (mu U/ml)  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                94
# 4                               168
# ..                              ...
# 763                             180
# 764                               0
# 765                             112
# 766                               0
# 767                               0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 0                                              33.6
# 1                                              26.6
# 2                                              23.3
# 3                                              28.1
# 4                                              43.1
# ..                                              ...
# 763                                            32.9
# 764                                            36.8
# 765                                            26.2
# 766                                            30.1
# 767                                            30.4
#
#      Diabetes pedigree function  Age (years)  Class variable
# 0                         0.627           50               1
# 1                         0.351           31               0
# 2                         0.672           32               1
# 3                         0.167           21               0
# 4                         2.288           33               1
# ..                          ...          ...             ...
# 763                       0.171           63               0
# 764                       0.340           27               0
# 765                       0.245           30               0
# 766                       0.349           47               1
# 767                       0.315           23               0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### Building model

# %%
# the classification experiment

from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()

# %%
# initializing the setup in experiment
from pycaret.classification import setup

setup(data, target="Class variable", session_id=124)
# Out:
# <style type="text/css">
# #T_9bfa6_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9bfa6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bfa6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9bfa6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bfa6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bfa6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9bfa6_row0_col1" class="data row0 col1" >124</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9bfa6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9bfa6_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9bfa6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9bfa6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9bfa6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9bfa6_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9bfa6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9bfa6_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9bfa6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9bfa6_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9bfa6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9bfa6_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9bfa6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9bfa6_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9bfa6_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_9bfa6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9bfa6_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_9bfa6_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9bfa6_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_9bfa6_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9bfa6_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_9bfa6_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9bfa6_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_9bfa6_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9bfa6_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_9bfa6_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9bfa6_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_9bfa6_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9bfa6_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_9bfa6_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9bfa6_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_9bfa6_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9bfa6_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_9bfa6_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9bfa6_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_9bfa6_row18_col1" class="data row18 col1" >4914</td>
#     </tr>
#   </tbody>
# </table>

# %%
# training the models

best = exp.compare_models()
# Out:
# <style type="text/css">
# #T_6d903 th {
#   text-align: left;
# }
# #T_6d903_row0_col0, #T_6d903_row0_col2, #T_6d903_row0_col3, #T_6d903_row0_col4, #T_6d903_row1_col0, #T_6d903_row1_col1, #T_6d903_row1_col2, #T_6d903_row1_col3, #T_6d903_row1_col5, #T_6d903_row1_col6, #T_6d903_row1_col7, #T_6d903_row2_col0, #T_6d903_row2_col1, #T_6d903_row2_col3, #T_6d903_row2_col4, #T_6d903_row2_col5, #T_6d903_row2_col6, #T_6d903_row2_col7, #T_6d903_row3_col0, #T_6d903_row3_col1, #T_6d903_row3_col2, #T_6d903_row3_col3, #T_6d903_row3_col4, #T_6d903_row3_col5, #T_6d903_row3_col6, #T_6d903_row3_col7, #T_6d903_row4_col0, #T_6d903_row4_col1, #T_6d903_row4_col2, #T_6d903_row4_col3, #T_6d903_row4_col4, #T_6d903_row4_col5, #T_6d903_row4_col6, #T_6d903_row4_col7, #T_6d903_row5_col0, #T_6d903_row5_col1, #T_6d903_row5_col2, #T_6d903_row5_col3, #T_6d903_row5_col4, #T_6d903_row5_col5, #T_6d903_row5_col6, #T_6d903_row5_col7, #T_6d903_row6_col0, #T_6d903_row6_col1, #T_6d903_row6_col2, #T_6d903_row6_col4, #T_6d903_row6_col5, #T_6d903_row6_col6, #T_6d903_row6_col7, #T_6d903_row7_col0, #T_6d903_row7_col1, #T_6d903_row7_col2, #T_6d903_row7_col3, #T_6d903_row7_col4, #T_6d903_row7_col5, #T_6d903_row7_col6, #T_6d903_row7_col7, #T_6d903_row8_col0, #T_6d903_row8_col1, #T_6d903_row8_col2, #T_6d903_row8_col3, #T_6d903_row8_col4, #T_6d903_row8_col5, #T_6d903_row8_col6, #T_6d903_row8_col7, #T_6d903_row9_col0, #T_6d903_row9_col1, #T_6d903_row9_col2, #T_6d903_row9_col3, #T_6d903_row9_col4, #T_6d903_row9_col5, #T_6d903_row9_col6, #T_6d903_row9_col7, #T_6d903_row10_col0, #T_6d903_row10_col1, #T_6d903_row10_col2, #T_6d903_row10_col3, #T_6d903_row10_col4, #T_6d903_row10_col5, #T_6d903_row10_col6, #T_6d903_row10_col7, #T_6d903_row11_col0, #T_6d903_row11_col1, #T_6d903_row11_col2, #T_6d903_row11_col3, #T_6d903_row11_col4, #T_6d903_row11_col5, #T_6d903_row11_col6, #T_6d903_row11_col7, #T_6d903_row12_col0, #T_6d903_row12_col1, #T_6d903_row12_col2, #T_6d903_row12_col3, #T_6d903_row12_col4, #T_6d903_row12_col5, #T_6d903_row12_col6, #T_6d903_row12_col7, #T_6d903_row13_col0, #T_6d903_row13_col1, #T_6d903_row13_col2, #T_6d903_row13_col3, #T_6d903_row13_col4, #T_6d903_row13_col5, #T_6d903_row13_col6, #T_6d903_row13_col7, #T_6d903_row14_col0, #T_6d903_row14_col1, #T_6d903_row14_col2, #T_6d903_row14_col3, #T_6d903_row14_col4, #T_6d903_row14_col5, #T_6d903_row14_col6, #T_6d903_row14_col7, #T_6d903_row15_col0, #T_6d903_row15_col1, #T_6d903_row15_col2, #T_6d903_row15_col3, #T_6d903_row15_col4, #T_6d903_row15_col5, #T_6d903_row15_col6, #T_6d903_row15_col7 {
#   text-align: left;
# }
# #T_6d903_row0_col1, #T_6d903_row0_col5, #T_6d903_row0_col6, #T_6d903_row0_col7, #T_6d903_row1_col4, #T_6d903_row2_col2, #T_6d903_row6_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6d903_row0_col8, #T_6d903_row1_col8, #T_6d903_row2_col8, #T_6d903_row3_col8, #T_6d903_row4_col8, #T_6d903_row5_col8, #T_6d903_row6_col8, #T_6d903_row7_col8, #T_6d903_row8_col8, #T_6d903_row9_col8, #T_6d903_row10_col8, #T_6d903_row11_col8, #T_6d903_row12_col8, #T_6d903_row13_col8, #T_6d903_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6d903_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6d903" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d903_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6d903_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6d903_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6d903_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6d903_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6d903_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6d903_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6d903_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6d903_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d903_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_6d903_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_6d903_row0_col1" class="data row0 col1" >0.7653</td>
#       <td id="T_6d903_row0_col2" class="data row0 col2" >0.8210</td>
#       <td id="T_6d903_row0_col3" class="data row0 col3" >0.5880</td>
#       <td id="T_6d903_row0_col4" class="data row0 col4" >0.6949</td>
#       <td id="T_6d903_row0_col5" class="data row0 col5" >0.6314</td>
#       <td id="T_6d903_row0_col6" class="data row0 col6" >0.4625</td>
#       <td id="T_6d903_row0_col7" class="data row0 col7" >0.4697</td>
#       <td id="T_6d903_row0_col8" class="data row0 col8" >0.2480</td>
#     </tr>
#     <tr>
#       <th id="T_6d903_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_6d903_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_6d903_row1_col1" class="data row1 col1" >0.7541</td>
#       <td id="T_6d903_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_6d903_row1_col3" class="data row1 col3" >0.5292</td>
#       <td id="T_6d903_row1_col4" class="data row1 col4" >0.6976</td>
#       <td id="T_6d903_row1_col5" class="data row1 col5" >0.5962</td>
#       <td id="T_6d903_row1_col6" class="data row1 col6" >0.4259</td>
#       <td id="T_6d903_row1_col7" class="data row1 col7" >0.4375</td>
#       <td id="T_6d903_row1_col8" class="data row1 col8" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_6d903_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_6d903_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_6d903_row2_col1" class="data row2 col1" >0.7523</td>
#       <td id="T_6d903_row2_col2" class="data row2 col2" >0.8250</td>
#       <td id="T_6d903_row2_col3" class="data row2 col3" >0.5345</td>
#       <td id="T_6d903_row2_col4" class="data row2 col4" >0.6894</td>
#       <td id="T_6d903_row2_col5" class="data row2 col5" >0.5957</td>
#       <td id="T_6d903_row2_col6" class="data row2 col6" >0.4232</td>
#       <td id="T_6d903_row2_col7" class="data row2 col7" >0.4340</td>
#       <td id="T_6d903_row2_col8" class="data row2 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_6d903_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_6d903_row3_col0" class="data row3 col0" >CatBoost Classifier</td>
#       <td id="T_6d903_row3_col1" class="data row3 col1" >0.7523</td>
#       <td id="T_6d903_row3_col2" class="data row3 col2" >0.8234</td>
#       <td id="T_6d903_row3_col3" class="data row3 col3" >0.5830</td>
#       <td id="T_6d903_row3_col4" class="data row3 col4" >0.6725</td>
#       <td id="T_6d903_row3_col5" class="data row3 col5" >0.6199</td>
#       <td id="T_6d903_row3_col6" class="data row3 col6" >0.4386</td>
#       <td id="T_6d903_row3_col7" class="data row3 col7" >0.4444</td>
#       <td id="T_6d903_row3_col8" class="data row3 col8" >2.4490</td>
#     </tr>
#     <tr>
#       <th id="T_6d903_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_6d903_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_6d903_row4_col1" class="data row4 col1" >0.7522</td>
#       <td id="T_6d903_row4_col2" class="data row4 col2" >0.8098</td>
#       <td id="T_6d903_row4_col3" class="data row4 col3" >0.5336</td>
#       <td id="T_6d903_row4_col4" class="data row4 col4" >0.6850</td>
#       <td id="T_6d903_row4_col5" class="data row4 col5" >0.5955</td>
#       <td id="T_6d903_row4_col6" class="data row4 col6" >0.4223</td>
#       <td id="T_6d903_row4_col7" class="data row4 col7" >0.4313</td>
#       <td id="T_6d903_row4_col8" class="data row4 col8" >0.2440</td>
#     </tr>
#     <tr>
#       <th id="T_6d903_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_6d903_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_6d903_row5_col1" class="data row5 col1" >0.7505</td>
#       <td id="T_6d903_row5_col2" class
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]

# %% [markdown]
# Now it's time to analyse the model

# %% [markdown]
# ### Visualising the model res

# %%
from pycaret.classification import plot_model

# confusion matrix
plot_model(best, plot="confusion_matrix")

# %%
# plot AUC

plot_model(best, plot = 'auc')

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %% [markdown]
# ### Model evaluation

# %%
# evaluation of the model

from pycaret.classification import evaluate_model

evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Model prediction

# %%
# prediction
from pycaret.classification import predict_model

prediction = predict_model(best)
prediction.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d602a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d602a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d602a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d602a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d602a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d602a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d602a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d602a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d602a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d602a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d602a_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_d602a_row0_col1" class="data row0 col1" >0.7749</td>
#       <td id="T_d602a_row0_col2" class="data row0 col2" >0.8490</td>
#       <td id="T_d602a_row0_col3" class="data row0 col3" >0.6667</td>
#       <td id="T_d602a_row0_col4" class="data row0 col4" >0.6835</td>
#       <td id="T_d602a_row0_col5" class="data row0 col5" >0.6750</td>
#       <td id="T_d602a_row0_col6" class="data row0 col6" >0.5029</td>
#       <td id="T_d602a_row0_col7" class="data row0 col7" >0.5029</td>
#     </tr>
#   </tbody>
# </table>
#      Number of times pregnant  \
# 296                         2
# 6                           3
# 70                          2
# 267                         2
# 100                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 296                                                146
# 6                                                   78
# 70                                                 100
# 267                                                128
# 100                                                163
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 296                                70                                38
# 6                                  50                                32
# 70                                 66                                20
# 267                                64                                42
# 100                                72                                 0
#
#      2-Hour serum insulin (mu U/ml)  \
# 296                             360
# 6                                88
# 70                               90
# 267                               0
# 100                               0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 296                                       28.000000
# 6                                         31.000000
# 70                                        32.900002
# 267                                       40.000000
# 100                                       39.000000
#
#      Diabetes pedigree function  Age (years)  Class variable  \
# 296                       0.337           29               1
# 6                         0.248           26               1
# 70                        0.867           28               1
# 267                       1.101           24               0
# 100                       1.222           33               1
#
#      prediction_label  prediction_score
# 296                 0              0.60
# 6                   0              0.96
# 70                  0              0.89
# 267                 1              0.51
# 100                 1              0.76

# %%
# for new data

new_data = data.copy()
new_data.drop('Class variable', axis=1, inplace=True)
new_data = new_data.sample(10)
new_data
# Out:
#      Number of times pregnant  \
# 47                          2
# 434                         1
# 242                         3
# 139                         5
# 694                         2
# 650                         1
# 412                         1
# 741                         3
# 287                         1
# 604                         4
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 47                                                  71
# 434                                                 90
# 242                                                139
# 139                                                105
# 694                                                 90
# 650                                                 91
# 412                                                143
# 741                                                102
# 287                                                119
# 604                                                183
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 47                                 70                                27
# 434                                68                                 8
# 242                                54                                 0
# 139                                72                                29
# 694                                60                                 0
# 650                                54                                25
# 412                                84                                23
# 741                                44                                20
# 287                                86                                39
# 604                                 0                                 0
#
#      2-Hour serum insulin (mu U/ml)  \
# 47                                0
# 434                               0
# 242                               0
# 139                             325
# 694                               0
# 650                             100
# 412                             310
# 741                              94
# 287                             220
# 604                               0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 47                                             28.0
# 434                                            24.5
# 242                                            25.6
# 139                                            36.9
# 694                                            23.5
# 650                                            25.2
# 412                                            42.4
# 741                                            30.8
# 287                                            45.6
# 604                                            28.4
#
#      Diabetes pedigree function  Age (years)
# 47                        0.586           22
# 434                       1.138           36
# 242                       0.402           22
# 139                       0.159           28
# 694                       0.191           25
# 650                       0.234           23
# 412                       1.076           22
# 741                       0.400           26
# 287                       0.808           29
# 604                       0.212           36

# %%
# predict model on new_data
predictions = predict_model(best, data = new_data)
predictions.head()
# Out:
#      Number of times pregnant  \
# 47                          2
# 434                         1
# 242                         3
# 139                         5
# 694                         2
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 47                                                  71
# 434                                                 90
# 242                                                139
# 139                                                105
# 694                                                 90
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 47                                 70                                27
# 434                                68                                 8
# 242                                54                                 0
# 139                                72                                29
# 694                                60                                 0
#
#      2-Hour serum insulin (mu U/ml)  \
# 47                                0
# 434                               0
# 242                               0
# 139                             325
# 694                               0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 47                                        28.000000
# 434                                       24.500000
# 242                                       25.600000
# 139                                       36.900002
# 694                                       23.500000
#
#      Diabetes pedigree function  Age (years)  prediction_label  \
# 47                        0.586           22                 0
# 434                       1.138           36                 0
# 242                       0.402           22                 1
# 139                       0.159           28                 0
# 694                       0.191           25                 0
#
#      prediction_score
# 47               0.98
# 434              0.96
# 242              0.74
# 139              0.92
# 694              1.00

# %% [markdown]
# ### Saving the model

# %%
from pycaret.classification import save_model

save_model(best, "binary_classify_pipeline")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Number of times pregnant',
#                                               'Plasma glucose concentration a 2 '
#                                               'hours in an oral glucose '
#                                               'tolerance test',
#                                               'Diastolic blood pressure (mm Hg)',
#                                               'Triceps skin fold thickness (mm)',
#                                               '2-Hour serum insulin (mu U/ml)',
#                                               'Body mass index (weight in '
#                                               'kg/(height in m)^2)',
#                                               'Diabetes pedigre...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=100, n_jobs=-1,
#                                          oob_score=False, random_state=124,
#                                          verbose=0, warm_start=False))],
#           verbose=False),
#  'binary_classify_pipeline.pkl')

# %% [markdown]
# ### Loading the saved model

# %%
from pycaret.classification import load_model

loaded = load_model("binary_classify_pipeline")
loaded
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Number of times pregnant',
#                                              'Plasma glucose concentration a 2 '
#                                              'hours in an oral glucose '
#                                              'tolerance test',
#                                              'Diastolic blood pressure (mm Hg)',
#                                              'Triceps skin fold thickness (mm)',
#                                              '2-Hour serum insulin (mu U/ml)',
#                                              'Body mass index (weight in '
#                                              'kg/(height in m)^2)',
#                                              'Diab...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='sqrt',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=-1,
#                                         oob_score=False, random_state=124,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %% [markdown]
# ## Multiclass Classification

# %% [markdown]
# ### Getting the data

# %%
from pycaret.datasets import get_data
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Building the model

# %%
setup(data, target = 'species', session_id = 143)
# Out:
# <style type="text/css">
# #T_98ce6_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_98ce6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98ce6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_98ce6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98ce6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98ce6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_98ce6_row0_col1" class="data row0 col1" >143</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98ce6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_98ce6_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98ce6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_98ce6_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98ce6_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_98ce6_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98ce6_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_98ce6_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_98ce6_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_98ce6_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_98ce6_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_98ce6_row6_col1" class="data row6 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_98ce6_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_98ce6_row7_col1" class="data row7 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_98ce6_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_98ce6_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_98ce6_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_98ce6_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_98ce6_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_98ce6_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_98ce6_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_98ce6_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_98ce6_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_98ce6_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_98ce6_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_98ce6_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_98ce6_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_98ce6_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_98ce6_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_98ce6_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_98ce6_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_98ce6_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_98ce6_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_98ce6_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_98ce6_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_98ce6_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_98ce6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_98ce6_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_98ce6_row19_col1" class="data row19 col1" >e0d6</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import ClassificationExperiment, setup
exp_2 = ClassificationExperiment()

exp_2.setup(data, target = 'species', session_id = 143)
# Out:
# <style type="text/css">
# #T_d7a8f_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_
col8" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_ffc91_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ffc91_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_ffc91_row2_col1" class="data row2 col1" >0.9709</td>
#       <td id="T_ffc91_row2_col2" class="data row2 col2" >0.9976</td>
#       <td id="T_ffc91_row2_col3" class="data row2 col3" >0.9709</td>
#       <td id="T_ffc91_row2_col4" class="data row2 col4" >0.9777</td>
#       <td id="T_ffc91_row2_col5" class="data row2 col5" >0.9705</td>
#       <td id="T_ffc91_row2_col6" class="data row2 col6" >0.9561</td>
#       <td id="T_ffc91_row2_col7" class="data row2 col7" >0.9598</td>
#       <td id="T_ffc91_row2_col8" class="data row2 col8" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_ffc91_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_ffc91_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_ffc91_row3_col1" class="data row3 col1" >0.9709</td>
#       <td id="T_ffc91_row3_col2" class="data row3 col2" >0.9976</td>
#       <td id="T_ffc91_row3_col3" class="data row3 col3" >0.9709</td>
#       <td id="T_ffc91_row3_col4" class="data row3 col4" >0.9777</td>
#       <td id="T_ffc91_row3_col5" class="data row3 col5" >0.9705</td>
#       <td id="T_ffc91_row3_col6" class="data row3 col6" >0.9561</td>
#       <td id="T_ffc91_row3_col7" class="data row3 col7" >0.9598</td>
#       <td id="T_ffc91_row3_col8" class="data row3 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_ffc91_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_ffc91_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_ffc91_row4_col1" class="data row4 col1" >0.9709</td>
#       <td id="T_ffc91_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_ffc91_row4_col3" class="data row4 col3" >0.9709</td>
#       <td id="T_ffc91_row4_col4" class="data row4 col4" >0.9777</td>
#       <td id="T_ffc91_row4_col5" class="data row4 col5" >0.9705</td>
#       <td id="T_ffc91_row4_col6" class="data row4 col6" >0.9561</td>
#       <td id="T_ffc91_row4_col7" class="data row4 col7" >0.9598</td>
#       <td id="T_ffc91_row4_col8" class="data row4 col8" >0.1830</td>
#     </tr>
#     <tr>
#       <th id="T_ffc91_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_ffc91_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_ffc91_row5_col1" class="data row5 col1" >0.9709</td>
#       <td id="T_ffc91_row5_col2" class
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]
# CPU times: user 6.96 s, sys: 166 ms, total: 7.13 s
# Wall time: 32.2 s

# %% [markdown]
# ### Plotting

# %%
from pycaret.classification import plot_model

# plot confusion matrix
plot_model(best_clf, plot = 'confusion_matrix')

# %%
# plot AUC
plot_model(best_clf, plot = 'auc')

# %%
# plot feature importance
plot_model(best_clf, plot = 'feature')

# %% [markdown]
# ### Model Evaluation

# %%
evaluate_model(best_clf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### customizing

# %%
# getting the current config

from pycaret.classification import get_config
get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %%
from pycaret.classification import models
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# catboost                   catboost.core.CatBoostClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
# custom models
from pycaret.classification import compare_models

compare_tree_models = compare_models(include = ['dt', 'rf', 'et',])
# Out:
# <style type="text/css">
# #T_37afd th {
#   text-align: left;
# }
# #T_37afd_row0_col0, #T_37afd_row1_col0, #T_37afd_row1_col1, #T_37afd_row1_col2, #T_37afd_row1_col3, #T_37afd_row1_col4, #T_37afd_row1_col5, #T_37afd_row1_col6, #T_37afd_row1_col7, #T_37afd_row2_col0, #T_37afd_row2_col1, #T_37afd_row2_col2, #T_37afd_row2_col3, #T_37afd_row2_col4, #T_37afd_row2_col5, #T_37afd_row2_col6, #T_37afd_row2_col7 {
#   text-align: left;
# }
# #T_37afd_row0_col1, #T_37afd_row0_col2, #T_37afd_row0_col3, #T_37afd_row0_col4, #T_37afd_row0_col5, #T_37afd_row0_col6, #T_37afd_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_37afd_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_37afd_row1_col8, #T_37afd_row2_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_37afd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37afd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_37afd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_37afd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_37afd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_37afd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_37afd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_37afd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_37afd_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_37afd_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37afd_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_37afd_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_37afd_row0_col1" class="data row0 col1" >0.9709</td>
#       <td id="T_37afd_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_37afd_row0_col3" class="data row0 col3" >0.9709</td>
#       <td id="T_37afd_row0_col4" class="data row0 col4" >0.9777</td>
#       <td id="T_37afd_row0_col5" class="data row0 col5" >0.9705</td>
#       <td id="T_37afd_row0_col6" class="data row0 col6" >0.9561</td>
#       <td id="T_37afd_row0_col7" class="data row0 col7" >0.9598</td>
#       <td id="T_37afd_row0_col8" class="data row0 col8" >0.1810</td>
#     </tr>
#     <tr>
#       <th id="T_37afd_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_37afd_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_37afd_row1_col1" class="data row1 col1" >0.9618</td>
#       <td id="T_37afd_row1_col2" class="data row1 col2" >0.9711</td>
#       <td id="T_37afd_row1_col3" class="data row1 col3" >0.9618</td>
#       <td id="T_37afd_row1_col4" class="data row1 col4" >0.9704</td>
#       <td id="T_37afd_row1_col5" class="data row1 col5" >0.9610</td>
#       <td id="T_37afd_row1_col6" class="data row1 col6" >0.9422</td>
#       <td id="T_37afd_row1_col7" class="data row1 col7" >0.9471</td>
#       <td id="T_37afd_row1_col8" class="data row1 col8" >0.8540</td>
#     </tr>
#     <tr>
#       <th id="T_37afd_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_37afd_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_37afd_row2_col1" class="data row2 col1" >0.9618</td>
#       <td id="T_37afd_row2_col2" class="data row2 col2" >0.9976</td>
#       <td id="T_37afd_row2_col3" class="data row2 col3" >0.9618</td>
#       <td id="T_37afd_row2_col4" class="data row2 col4" >0.9704</td>
#       <td id="T_37afd_row2_col5" class="data row2 col5" >0.9610</td>
#       <td id="T_37afd_row2_col6" class="data row2 col6" >0.9422</td>
#       <td id="T_37afd_row2_col7" class="data row2 col7" >0.9471</td>
#       <td id="T_37afd_row2_col8" class="data row2 col8" >0.2190</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/17 [00:00<?, ?it/s]

# %%
# get all of the metrics

from pycaret.classification import pull
pull()
# Out:
#                        Model  Accuracy     AUC  Recall   Prec.      F1  \
# et    Extra Trees Classifier    0.9709  1.0000  0.9709  0.9777  0.9705
# dt  Decision Tree Classifier    0.9618  0.9711  0.9618  0.9704  0.9610
# rf  Random Forest Classifier    0.9618  0.9976  0.9618  0.9704  0.9610
#
#      Kappa     MCC  TT (Sec)
# et  0.9561  0.9598     0.181
# dt  0.9422  0.9471     0.854
# rf  0.9422  0.9471     0.219

# %% [markdown]
# ## Regression

# %% [markdown]
# ## Time Series Forecasting

# %% [markdown]
# ## Clustering

# %% [markdown]
# ## Anomaly Detection
