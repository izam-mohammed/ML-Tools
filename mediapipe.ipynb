# %% [markdown]
# **Things we can do with mediapipe**
#
# 1. Object Detection
# 1. Image Classification
# 1. Image Segmentation
# 1. Interactive Segmentation
# 1. Gesture Recognition
# 1. Hand Landmark Detection
# 1. Image Embedding
# 1. Face Stylization
# 1. Face Detection
# 1. Face Landmark Detection
# 1. Pose Landmark Detection
# 1. Text Classification
# 1. Text Embedding
# 1. Language Detection
# 1. Audio Classification

# %% [markdown]
# All of the **code files** [available here](https://github.com/googlesamples/mediapipe/tree/main/examples)
#
# All of the **demos** [available here](https://mediapipe-studio.webapps.google.com/home)

# %% [markdown]
# Thanks for reading this
