# %% [markdown]
# ### importing

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### DataFrame

# %% [markdown]
# A two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
# a sample dataframe

data = {"hai":[1,2,3,4,5],
        "hello":[5,2,5,7,8]
        }
df = pd.DataFrame(data)
df
# Out:
#    hai  hello
# 0    1      5
# 1    2      2
# 2    3      5
# 3    4      7
# 4    5      8

# %% [markdown]
# ### Creation of df

# %%
# from dict of lists

data = {'Column1': [1, 2, 3],
        'Column2': ['A', 'B', 'C']}
df = pd.DataFrame(data)
df
# Out:
#    Column1 Column2
# 0        1       A
# 1        2       B
# 2        3       C

# %%
# from list of directories

data = [{'Column1': 1, 'Column2': 'A'},
        {'Column1': 2, 'Column2': 'B'},
        {'Column1': 3, 'Column2': 'C'}]
df = pd.DataFrame(data)
df
# Out:
#    Column1 Column2
# 0        1       A
# 1        2       B
# 2        3       C

# %%
# From a List of Lists with Columns and Index Specified

data = [[1, 'A'], [2, 'B'], [3, 'C']]
columns = ['Column1', 'Column2']
index = ['Row1', 'Row2', 'Row3']
df = pd.DataFrame(data, columns=columns, index=index)
df
# Out:
#       Column1 Column2
# Row1        1       A
# Row2        2       B
# Row3        3       C

# %%
# from numpy array

data = np.array([[1, 'A'], [2, 'B'], [3, 'C']])
df = pd.DataFrame(data, columns=['Column1', 'Column2'])
df
# Out:
#   Column1 Column2
# 0       1       A
# 1       2       B
# 2       3       C

# %%
# from a dictionary of series

data = {'Column1': pd.Series([1, 2, 3]),
        'Column2': pd.Series(['A', 'B', 'C'])}
df = pd.DataFrame(data)
df
# Out:
#    Column1 Column2
# 0        1       A
# 1        2       B
# 2        3       C

# %% [markdown]
# ### Reading the data to df

# %%
# from a csv

df = pd.read_csv('data.csv')
df.sample(5)
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 16011  C_CND_016012   7/19/2023         Malky    Male        1210000
# 13747  C_CND_013748   5/17/2023           Leo    Male        1500000
# 11547  C_CND_011548    3/1/2023       Addison    Male         291000
# 19573  C_CND_019574  10/14/2023      Clarisse  Female          13500
# 23835  C_CND_023836  12/30/2023          Ezra    Male         645000
#
#                            Dealer_Name     Company          Model  \
# 16011                    Race Car Help  Mitsubishi  Montero Sport
# 13747            Enterprise Rent A Car     Mercury  Grand Marquis
# 11547  New Castle Ford Lincoln Mercury       Honda           CR-V
# 19573             Rabun Used Car Sales   Chevrolet         Malibu
# 23835                  Pars Auto Sales        Audi             A6
#
#                           Engine Transmission       Color  Price ($)  \
# 16011  DoubleÂ Overhead Camshaft         Auto       Black      45000
# 13747          Overhead Camshaft       Manual       Black      49001
# 11547  DoubleÂ Overhead Camshaft         Auto  Pale White      22001
# 19573          Overhead Camshaft       Manual  Pale White      57001
# 23835  DoubleÂ Overhead Camshaft         Auto  Pale White      42000
#
#        Dealer_No  Body Style    Phone Dealer_Region
# 16011  78758-7841    Hardtop  8256372        Austin
# 13747  60504-7114        SUV  8583689        Aurora
# 11547  60504-7114        SUV  8396570        Aurora
# 19573  85257-3102    Hardtop  6126479         Pasco
# 23835  38701-8047        SUV  7833423    Greenville

# %%
# from an excel file

df = pd.read_excel("data.xlsx", sheet_name="data")
df.head()
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price ($)  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto       Black      26000  06457-3834
# 1  DoubleÂ Overhead Camshaft         Auto       Black      19000  60504-7114
# 2          Overhead Camshaft       Manual         Red      31500  38701-8047
# 3          Overhead Camshaft       Manual  Pale White      14000  99301-3882
# 4  DoubleÂ Overhead Camshaft         Auto         Red      24500  53546-9427
#
#   Body Style    Phone Dealer_Region
# 0        SUV  8264678    Middletown
# 1        SUV  6848189        Aurora
# 2  Passenger  7298798    Greenville
# 3        SUV  6257557         Pasco
# 4  Hatchback  7081483    Janesville

# %%
# From a URL

url = "https://support.staffbase.com/hc/en-us/article_attachments/360009197031/username.csv"
df = pd.read_csv(url, delimiter=";")
df.head()
# Out:
#     Username   Identifier First name Last name
# 0   booker12         9012     Rachel    Booker
# 1     grey07         2070      Laura      Grey
# 2  johnson81         4081      Craig   Johnson
# 3  jenkins46         9346       Mary   Jenkins
# 4    smith79         5079      Jamie     Smith

# %% [markdown]
# ### Viewing df

# %%
# the upper part

df.head()
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price ($)  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto       Black      26000  06457-3834
# 1  DoubleÂ Overhead Camshaft         Auto       Black      19000  60504-7114
# 2          Overhead Camshaft       Manual         Red      31500  38701-8047
# 3          Overhead Camshaft       Manual  Pale White      14000  99301-3882
# 4  DoubleÂ Overhead Camshaft         Auto         Red      24500  53546-9427
#
#   Body Style    Phone Dealer_Region
# 0        SUV  8264678    Middletown
# 1        SUV  6848189        Aurora
# 2  Passenger  7298798    Greenville
# 3        SUV  6257557         Pasco
# 4  Hatchback  7081483    Janesville

# %%
# the lower part

df.tail()
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                           Dealer_Name    Company    Model  \
# 23901                C & M Motors Inc   Plymouth  Voyager
# 23902  Ryder Truck Rental and Leasing  Chevrolet    Prizm
# 23903          Chrysler of Tri-Cities        BMW     328i
# 23904               Chrysler Plymouth  Chevrolet    Metro
# 23905                 Pars Auto Sales      Lexus    ES300
#
#                           Engine Transmission       Color  Price ($)  \
# 23901          Overhead Camshaft       Manual         Red      12000
# 23902  DoubleÂ Overhead Camshaft         Auto       Black      16000
# 23903          Overhead Camshaft       Manual         Red      21000
# 23904  DoubleÂ Overhead Camshaft         Auto       Black      31000
# 23905  DoubleÂ Overhead Camshaft         Auto  Pale White      27500
#
#        Dealer_No  Body Style    Phone Dealer_Region
# 23901  60504-7114  Passenger  8583598         Pasco
# 23902  06457-3834    Hardtop  7914229    Middletown
# 23903  99301-3882      Sedan  7659127    Scottsdale
# 23904  53546-9427  Passenger  6030764        Austin
# 23905  38701-8047    Hardtop  7020564    Middletown

# %%
# some random sample in data

df.sample(5)
# Out:
#              Car_id       Date Customer Name Gender  Annual Income  \
# 15846  C_CND_015847  7/16/2023       Natalie   Male          13500
# 3048   C_CND_003049   6/9/2022        Gianna   Male          13500
# 11044  C_CND_011045  1/30/2023        Darren   Male          13500
# 6262   C_CND_006263  9/25/2022      Savannah   Male          13500
# 2799   C_CND_002800  5/30/2022        Saruul   Male         763000
#
#                  Dealer_Name     Company       Model  \
# 15846      Chrysler Plymouth     Pontiac    Grand Am
# 3048           Race Car Help     Pontiac  Bonneville
# 11044         Nebo Chevrolet         BMW        328i
# 6262          Nebo Chevrolet       Dodge     Stratus
# 2799   Enterprise Rent A Car  Mercedes-B     E-Class
#
#                           Engine Transmission       Color  Price ($)  \
# 15846  DoubleÂ Overhead Camshaft         Auto  Pale White      12000
# 3048   DoubleÂ Overhead Camshaft         Auto         Red      19001
# 11044  DoubleÂ Overhead Camshaft         Auto       Black      16001
# 6262           Overhead Camshaft       Manual  Pale White      37001
# 2799   DoubleÂ Overhead Camshaft         Auto         Red      15000
#
#        Dealer_No  Body Style    Phone Dealer_Region
# 15846  53546-9427        SUV  6613431    Janesville
# 3048   78758-7841  Hatchback  8020549        Austin
# 11044  06457-3834      Sedan  6404473    Middletown
# 6262   06457-3834  Hatchback  6506805    Middletown
# 2799   60504-7114      Sedan  6087854        Aurora

# %% [markdown]
# ### Attributes of df

# %%
# getting the shape of the data

df.shape
# Out:
# (23906, 16)

# %%
# getting the columns

df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
# getting the index

df.index
# Out:
# RangeIndex(start=0, stop=23906, step=1)

# %%
# getting the size

df.size
# Out:
# 382496

# %%
# getting the data type of each columns

df.dtypes
# Out:
# Car_id           object
# Date             object
# Customer Name    object
# Gender           object
# Annual Income     int64
# Dealer_Name      object
# Company          object
# Model            object
# Engine           object
# Transmission     object
# Color            object
# Price ($)         int64
# Dealer_No        object
# Body Style       object
# Phone             int64
# Dealer_Region    object
# dtype: object

# %%
# getting some general info about df

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23906 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
# getting the value count of each column

df.count()
# Out:
# Car_id           23906
# Date             23906
# Customer Name    23906
# Gender           23906
# Annual Income    23906
# Dealer_Name      23906
# Company          23906
# Model            23906
# Engine           23906
# Transmission     23906
# Color            23906
# Price ($)        23906
# Dealer_No        23906
# Body Style       23906
# Phone            23906
# Dealer_Region    23906
# dtype: int64

# %% [markdown]
# ### Statistical Operations

# %%
# getting the statistical info of numerical data

df.describe()
# Out:
#        Annual Income     Price ($)         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %%
# getting the statistical info of non-numberic data

df.describe(include=["O"])
# Out:
#               Car_id      Date Customer Name Gender  \
# count          23906     23906         23906  23906
# unique         23906       612          3022      2
# top     C_CND_000001  9/5/2023        Thomas   Male
# freq               1       190            92  18798
#
#                                             Dealer_Name    Company     Model  \
# count                                             23906      23906     23906
# unique                                               28         30       154
# top     Progressive Shippers Cooperative Association No  Chevrolet  Diamante
# freq                                               1318       1819       418
#
#                            Engine Transmission       Color  Dealer_No   \
# count                       23906        23906       23906       23906
# unique                          2            2           3           7
# top     DoubleÂ Overhead Camshaft         Auto  Pale White  85257-3102
# freq                        12571        12571       11256        3814
#
#        Body Style Dealer_Region
# count       23906         23906
# unique          5             7
# top           SUV        Austin
# freq         6374          4135

# %%
# getting the correlation

df.corr(numeric_only=True)
# Out:
#                Annual Income  Price ($)     Phone
# Annual Income       1.000000   0.012065 -0.000351
# Price ($)           0.012065   1.000000 -0.000493
# Phone              -0.000351  -0.000493  1.000000

# %% [markdown]
# ### Selection and Indexing

# %%
# selecting a column

df["Date"] # will give as a series
# Out:
# 0          1/2/2022
# 1          1/2/2022
# 2          1/2/2022
# 3          1/2/2022
# 4          1/2/2022
#             ...
# 23901    12/31/2023
# 23902    12/31/2023
# 23903    12/31/2023
# 23904    12/31/2023
# 23905    12/31/2023
# Name: Date, Length: 23906, dtype: object

# %%
# Selects a row by integer location

df.iloc[1]
# Out:
# Car_id                        C_CND_000002
# Date                              1/2/2022
# Customer Name                          Gia
# Gender                                Male
# Annual Income                      1480000
# Dealer_Name               C & M Motors Inc
# Company                              Dodge
# Model                              Durango
# Engine           DoubleÂ Overhead Camshaft
# Transmission                          Auto
# Color                                Black
# Price ($)                            19000
# Dealer_No                       60504-7114
# Body Style                             SUV
# Phone                              6848189
# Dealer_Region                       Aurora
# Name: 1, dtype: object

# %%
# selecting a range by integer location

df.iloc[1:5]
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#               Dealer_Name   Company     Model                     Engine  \
# 1        C & M Motors Inc     Dodge   Durango  DoubleÂ Overhead Camshaft
# 2             Capitol KIA  Cadillac  Eldorado          Overhead Camshaft
# 3  Chrysler of Tri-Cities    Toyota    Celica          Overhead Camshaft
# 4       Chrysler Plymouth     Acura        TL  DoubleÂ Overhead Camshaft
#
#   Transmission       Color  Price ($)  Dealer_No  Body Style    Phone  \
# 1         Auto       Black      19000  60504-7114        SUV  6848189
# 2       Manual         Red      31500  38701-8047  Passenger  7298798
# 3       Manual  Pale White      14000  99301-3882        SUV  6257557
# 4         Auto         Red      24500  53546-9427  Hatchback  7081483
#
#   Dealer_Region
# 1        Aurora
# 2    Greenville
# 3         Pasco
# 4    Janesville

# %%
# df.loc[row_label]: Selects a row by label

df.loc[1]
# Out:
# Car_id                        C_CND_000002
# Date                              1/2/2022
# Customer Name                          Gia
# Gender                                Male
# Annual Income                      1480000
# Dealer_Name               C & M Motors Inc
# Company                              Dodge
# Model                              Durango
# Engine           DoubleÂ Overhead Camshaft
# Transmission                          Auto
# Color                                Black
# Price ($)                            19000
# Dealer_No                       60504-7114
# Body Style                             SUV
# Phone                              6848189
# Dealer_Region                       Aurora
# Name: 1, dtype: object

# %% [markdown]
# ### Filtering the data

# %%
df[df["Price ($)"]> 80000]
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 8      C_CND_000009    1/2/2022         Naomi    Male         815000
# 170    C_CND_000171   1/13/2022        Jordan    Male          13500
# 269    C_CND_000270   1/27/2022       Destiny  Female         825000
# 342    C_CND_000343    2/3/2022        Benson  Female         580000
# 358    C_CND_000359    2/6/2022       Matthew    Male        1326000
# ...             ...         ...           ...     ...            ...
# 23519  C_CND_023520  12/25/2023          Luca    Male        1250000
# 23576  C_CND_023577  12/26/2023       Cheskel    Male          13500
# 23711  C_CND_023712  12/29/2023        Gilian    Male         900000
# 23762  C_CND_023763  12/29/2023          Loan    Male        1234500
# 23809  C_CND_023810  12/29/2023         Louen    Male        2065000
#
#                                            Dealer_Name     Company  \
# 8                                 Rabun Used Car Sales   Chevrolet
# 170                  Scrivener Performance Engineering     Lincoln
# 269                                    Pars Auto Sales      Toyota
# 342                     Ryder Truck Rental and Leasing    Cadillac
# 358                               Star Enterprises Inc      Toyota
# ...                                                ...         ...
# 23519                                 Saab-Belle Dodge  Mercedes-B
# 23576                                    Race Car Help     Lincoln
# 23711                                      Capitol KIA    Cadillac
# 23762  Progressive Shippers Cooperative Association No     Lincoln
# 23809                                        U-Haul CO     Lincoln
#
#              Model             Engine Transmission       Color  Price ($)  \
# 8           Malibu  Overhead Camshaft       Manual  Pale White      82000
# 170    Continental  Overhead Camshaft       Manual  Pale White      82000
# 269         Tacoma  Overhead Camshaft       Manual  Pale White      82000
# 342       Eldorado  Overhead Camshaft       Manual       Black      85000
# 358           RAV4  Overhead Camshaft       Manual       Black      85600
# ...            ...                ...          ...         ...        ...
# 23519      S-Class  Overhead Camshaft       Manual       Black      85000
# 23576  Continental  Overhead Camshaft       Manual         Red      82000
# 23711     Eldorado  Overhead Camshaft       Manual       Black      85000
# 23762  Continental  Overhead Camshaft       Manual         Red      82450
# 23809  Continental  Overhead Camshaft       Manual         Red      82500
#
#        Dealer_No  Body Style    Phone Dealer_Region
# 8      85257-3102    Hardtop  7194857         Pasco
# 170    38701-8047  Passenger  6642461    Greenville
# 269    38701-8047  Hatchback  7848361    Greenville
# 342    06457-3834  Passenger  6417156        Aurora
# 358    99301-3882  Hatchback  8706152         Pasco
# ...           ...        ...      ...           ...
# 23519  60504-7114        SUV  8770456        Aurora
# 23576  78758-7841  Passenger  8452256        Austin
# 23711  38701-8047  Passenger  7788669    Greenville
# 23762  53546-9427  Passenger  7468114        Austin
# 23809  78758-7841  Passenger  6406323        Aurora
#
# [220 rows x 16 columns]

# %% [markdown]
# ### Sorting

# %%
sorted = df.sort_values(by=["Annual Income"], ascending=False)
sorted
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 14026  C_CND_014027   5/26/2023         Assia    Male       11200000
# 15675  C_CND_015676   7/10/2023         Sofia    Male        8000000
# 6150   C_CND_006151   9/22/2022       Makayla    Male        7650000
# 9996   C_CND_009997  12/17/2022        Peyton    Male        6800000
# 22407  C_CND_022408   12/5/2023          Josh    Male        6600000
# ...             ...         ...           ...     ...            ...
# 13086  C_CND_013087   4/22/2023        Madina    Male          13500
# 13084  C_CND_013085   4/22/2023         Alice  Female          13500
# 13081  C_CND_013082   4/22/2023       Anaclle  Female          13500
# 11953  C_CND_011954   3/13/2023          Cora  Female          13500
# 23451  C_CND_023452  12/24/2023          Andy    Male          10080
#
#                                            Dealer_Name     Company  \
# 14026                                        U-Haul CO  Oldsmobile
# 15675                      Motor Vehicle Branch Office  Mercedes-B
# 6150                                Tri-State Mack Inc     Hyundai
# 9996   Progressive Shippers Cooperative Association No         BMW
# 22407                Scrivener Performance Engineering     Mercury
# ...                                                ...         ...
# 13086                Scrivener Performance Engineering       Buick
# 13084                                 Saab-Belle Dodge       Honda
# 13081                               Diehl Motor CO Inc       Honda
# 11953                Scrivener Performance Engineering     Pontiac
# 23451            Pitre Buick-Pontiac-Gmc of Scottsdale    Infiniti
#
#              Model                     Engine Transmission       Color  \
# 14026      Bravada  DoubleÂ Overhead Camshaft         Auto       Black
# 15675      S-Class          Overhead Camshaft       Manual       Black
# 6150        Sonata          Overhead Camshaft       Manual  Pale White
# 9996          323i  DoubleÂ Overhead Camshaft         Auto  Pale White
# 22407        Sable  DoubleÂ Overhead Camshaft         Auto         Red
# ...            ...                        ...          ...         ...
# 13086  Park Avenue          Overhead Camshaft       Manual       Black
# 13084       Accord  DoubleÂ Overhead Camshaft         Auto  Pale White
# 13081     Passport          Overhead Camshaft       Manual  Pale White
# 11953   Bonneville  DoubleÂ Overhead Camshaft         Auto         Red
# 23451          I30          Overhead Camshaft       Manual         Red
#
#        Price ($)  Dealer_No  Body Style    Phone Dealer_Region
# 14026      26001  78758-7841  Hatchback  6085179        Austin
# 15675      85000  78758-7841        SUV  8315091        Austin
# 6150       21000  85257-3102        SUV  8246892        Aurora
# 9996       15000  53546-9427  Hatchback  8787073    Greenville
# 22407      39000  38701-8047      Sedan  6307543        Aurora
# ...          ...         ...        ...      ...           ...
# 13086      29001  38701-8047  Hatchback  7614329    Scottsdale
# 13084      19000  60504-7114      Sedan  6135153        Aurora
# 13081      27001  06457-3834    Hardtop  8683214    Middletown
# 11953      19001  38701-8047  Hatchback  7105022    Greenville
# 23451      22801  99301-3882    Hardtop  8231348         Pasco
#
# [23906 rows x 16 columns]

# %% [markdown]
# ### missing values

# %%
# checking for missing values

df.isna().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    0
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %% [markdown]
# there is no missing values in this dataframe, however we can explore the imputation methods

# %%
# droping the missing values

df_without_missing = df.dropna()
df_without_missing
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# 2                              Capitol KIA   Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities     Toyota      Celica
# 4                        Chrysler Plymouth      Acura          TL
# ...                                    ...        ...         ...
# 23901                     C & M Motors Inc   Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing  Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities        BMW        328i
# 23904                    Chrysler Plymouth  Chevrolet       Metro
# 23905                      Pars Auto Sales      Lexus       ES300
#
#                           Engine Transmission       Color  Price ($)  \
# 0      DoubleÂ Overhead Camshaft         Auto       Black      26000
# 1      DoubleÂ Overhead Camshaft         Auto       Black      19000
# 2              Overhead Camshaft       Manual         Red      31500
# 3              Overhead Camshaft       Manual  Pale White      14000
# 4      DoubleÂ Overhead Camshaft         Auto         Red      24500
# ...                          ...          ...         ...        ...
# 23901          Overhead Camshaft       Manual         Red      12000
# 23902  DoubleÂ Overhead Camshaft         Auto       Black      16000
# 23903          Overhead Camshaft       Manual         Red      21000
# 23904  DoubleÂ Overhead Camshaft         Auto       Black      31000
# 23905  DoubleÂ Overhead Camshaft         Auto  Pale White      27500
#
#        Dealer_No  Body Style    Phone Dealer_Region
# 0      06457-3834        SUV  8264678    Middletown
# 1      60504-7114        SUV  6848189        Aurora
# 2      38701-8047  Passenger  7298798    Greenville
# 3      99301-3882        SUV  6257557         Pasco
# 4      53546-9427  Hatchback  7081483    Janesville
# ...           ...        ...      ...           ...
# 23901  60504-7114  Passenger  8583598         Pasco
# 23902  06457-3834    Hardtop  7914229    Middletown
# 23903  99301-3882      Sedan  7659127    Scottsdale
# 23904  53546-9427  Passenger  6030764        Austin
# 23905  38701-8047    Hardtop  7020564    Middletown
#
# [23906 rows x 16 columns]

# %%
# filling the missing values

df_filled = df.fillna({"Customer Name": "unknown"})

# %% [markdown]
# can do the back fill or front fill using this method

# %% [markdown]
# ### Merging and concatinating

# %%
# concatenating on column

df1 = pd.read_csv("data.csv")
df2 = pd.read_excel("data.xlsx", sheet_name="data")

pd.concat([df1, df2], axis=1)
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# 2                              Capitol KIA   Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities     Toyota      Celica
# 4                        Chrysler Plymouth      Acura          TL
# ...                                    ...        ...         ...
# 23901                     C & M Motors Inc   Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing  Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities        BMW        328i
# 23904                    Chrysler Plymouth  Chevrolet       Metro
# 23905                      Pars Auto Sales      Lexus       ES300
#
#                           Engine Transmission  ...    Company       Model  \
# 0      DoubleÂ Overhead Camshaft         Auto  ...       Ford  Expedition
# 1      DoubleÂ Overhead Camshaft         Auto  ...      Dodge     Durango
# 2              Overhead Camshaft       Manual  ...   Cadillac    Eldorado
# 3              Overhead Camshaft       Manual  ...     Toyota      Celica
# 4      DoubleÂ Overhead Camshaft         Auto  ...      Acura          TL
# ...                          ...          ...  ...        ...         ...
# 23901          Overhead Camshaft       Manual  ...   Plymouth     Voyager
# 23902  DoubleÂ Overhead Camshaft         Auto  ...  Chevrolet       Prizm
# 23903          Overhead Camshaft       Manual  ...        BMW        328i
# 23904  DoubleÂ Overhead Camshaft         Auto  ...  Chevrolet       Metro
# 23905  DoubleÂ Overhead Camshaft         Auto  ...      Lexus       ES300
#
#                           Engine Transmission       Color Price ($)  \
# 0      DoubleÂ Overhead Camshaft         Auto       Black     26000
# 1      DoubleÂ Overhead Camshaft         Auto       Black     19000
# 2              Overhead Camshaft       Manual         Red     31500
# 3              Overhead Camshaft       Manual  Pale White     14000
# 4      DoubleÂ Overhead Camshaft         Auto         Red     24500
# ...                          ...          ...         ...       ...
# 23901          Overhead Camshaft       Manual         Red     12000
# 23902  DoubleÂ Overhead Camshaft         Auto       Black     16000
# 23903          Overhead Camshaft       Manual         Red     21000
# 23904  DoubleÂ Overhead Camshaft         Auto       Black     31000
# 23905  DoubleÂ Overhead Camshaft         Auto  Pale White     27500
#
#        Dealer_No  Body Style    Phone Dealer_Region
# 0      06457-3834        SUV  8264678    Middletown
# 1      60504-7114        SUV  6848189        Aurora
# 2      38701-8047  Passenger  7298798    Greenville
# 3      99301-3882        SUV  6257557         Pasco
# 4      53546-9427  Hatchback  7081483    Janesville
# ...           ...        ...      ...           ...
# 23901  60504-7114  Passenger  8583598         Pasco
# 23902  06457-3834    Hardtop  7914229    Middletown
# 23903  99301-3882      Sedan  7659127    Scottsdale
# 23904  53546-9427  Passenger  6030764        Austin
# 23905  38701-8047    Hardtop  7020564    Middletown
#
# [23906 rows x 32 columns]

# %%
# merging based on a key column

pd.merge(df1, df2, on="Car_id")
# Out:
#              Car_id      Date_x Customer Name_x Gender_x  Annual Income_x  \
# 0      C_CND_000001    1/2/2022       Geraldine     Male            13500
# 1      C_CND_000002    1/2/2022             Gia     Male          1480000
# 2      C_CND_000003    1/2/2022          Gianna     Male          1035000
# 3      C_CND_000004    1/2/2022         Giselle     Male            13500
# 4      C_CND_000005    1/2/2022           Grace     Male          1465000
# ...             ...         ...             ...      ...              ...
# 23901  C_CND_023902  12/31/2023          Martin     Male            13500
# 23902  C_CND_023903  12/31/2023           Jimmy   Female           900000
# 23903  C_CND_023904  12/31/2023            Emma     Male           705000
# 23904  C_CND_023905  12/31/2023        Victoire     Male            13500
# 23905  C_CND_023906  12/31/2023         Donovan     Male          1225000
#
#                              Dealer_Name_x  Company_x     Model_x  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# 2                              Capitol KIA   Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities     Toyota      Celica
# 4                        Chrysler Plymouth      Acura          TL
# ...                                    ...        ...         ...
# 23901                     C & M Motors Inc   Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing  Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities        BMW        328i
# 23904                    Chrysler Plymouth  Chevrolet       Metro
# 23905                      Pars Auto Sales      Lexus       ES300
#
#                         Engine_x Transmission_x  ...  Company_y     Model_y  \
# 0      DoubleÂ Overhead Camshaft           Auto  ...       Ford  Expedition
# 1      DoubleÂ Overhead Camshaft           Auto  ...      Dodge     Durango
# 2              Overhead Camshaft         Manual  ...   Cadillac    Eldorado
# 3              Overhead Camshaft         Manual  ...     Toyota      Celica
# 4      DoubleÂ Overhead Camshaft           Auto  ...      Acura          TL
# ...                          ...            ...  ...        ...         ...
# 23901          Overhead Camshaft         Manual  ...   Plymouth     Voyager
# 23902  DoubleÂ Overhead Camshaft           Auto  ...  Chevrolet       Prizm
# 23903          Overhead Camshaft         Manual  ...        BMW        328i
# 23904  DoubleÂ Overhead Camshaft           Auto  ...  Chevrolet       Metro
# 23905  DoubleÂ Overhead Camshaft           Auto  ...      Lexus       ES300
#
#                         Engine_y Transmission_y     Color_y Price ($)_y  \
# 0      DoubleÂ Overhead Camshaft           Auto       Black       26000
# 1      DoubleÂ Overhead Camshaft           Auto       Black       19000
# 2              Overhead Camshaft         Manual         Red       31500
# 3              Overhead Camshaft         Manual  Pale White       14000
# 4      DoubleÂ Overhead Camshaft           Auto         Red       24500
# ...                          ...            ...         ...         ...
# 23901          Overhead Camshaft         Manual         Red       12000
# 23902  DoubleÂ Overhead Camshaft           Auto       Black       16000
# 23903          Overhead Camshaft         Manual         Red       21000
# 23904  DoubleÂ Overhead Camshaft           Auto       Black       31000
# 23905  DoubleÂ Overhead Camshaft           Auto  Pale White       27500
#
#       Dealer_No _y Body Style_y  Phone_y  Dealer_Region_y
# 0       06457-3834          SUV  8264678       Middletown
# 1       60504-7114          SUV  6848189           Aurora
# 2       38701-8047    Passenger  7298798       Greenville
# 3       99301-3882          SUV  6257557            Pasco
# 4       53546-9427    Hatchback  7081483       Janesville
# ...            ...          ...      ...              ...
# 23901   60504-7114    Passenger  8583598            Pasco
# 23902   06457-3834      Hardtop  7914229       Middletown
# 23903   99301-3882        Sedan  7659127       Scottsdale
# 23904   53546-9427    Passenger  6030764           Austin
# 23905   38701-8047      Hardtop  7020564       Middletown
#
# [23906 rows x 31 columns]

# %% [markdown]
# ### Exporting the df

# %%
# exporting as csv file

df.to_csv("new_file.csv", index=False)

# %% [markdown]
# The end
