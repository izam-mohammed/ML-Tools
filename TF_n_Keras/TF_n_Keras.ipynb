# %% [markdown]
# **Tensorflow** is an end-to-end open source machine learning platform for everyone.

# %% [markdown]
# ### Getting libraries

# %%
import tensorflow as tf

# %% [markdown]
# ### Basic datatypes

# %%
# tensors  --> variable

variable = tf.Variable([1, 2, 3])
variable
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([1, 2, 3], dtype=int32)>

# %%
# tensors  --> Constant

constant_tensor = tf.constant([1, 2, 3])
constant_tensor
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([1, 2, 3], dtype=int32)>

# %% [markdown]
# ### Operations in tensors

# %% [markdown]
# ### tf function

# %%
@tf.function
def add(a, b):
    return a + b

# %%
print(add(1, 2))
# Out:
# tf.Tensor(3, shape=(), dtype=int32)

# %% [markdown]
# ### Optimizers

# %%
# Define an optimizer
optimizer = tf.optimizers.Adam(learning_rate=0.001)

# Use the optimizer in model training

# %% [markdown]
# ### Layers

# %%
# Define a dense layer
dense_layer = tf.keras.layers.Dense(units=128, activation='relu')

# %% [markdown]
# ### Model Training

# %% [markdown]
# ### Load and process data

# %% [markdown]
# includes
#
# - images
# - video
# - text
# - csv
# - numpy arr
# - pd dataframe
# - additional formats

# %% [markdown]
# ### Custom Training

# %% [markdown]
# ### Playing in Tensoflow Hub
