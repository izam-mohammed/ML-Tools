# %%
# !pip install python-box --quiet

# %%
# importing

from box import ConfigBox

# %%
# setting value

movie_box = ConfigBox({ "Robin Hood: Men in Tights": { "imdb stars": 6.7, "length": 104 } })

# %%
# getting value

movie_box.Robin_Hood_Men_in_Tights.imdb_stars
# Out:
# 6.7

# %% [markdown]
# that's it
